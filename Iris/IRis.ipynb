# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\RAGHAVENDRA KUMAR\Downloads\Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data1=data.copy()

# %%
data1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#from the above dataset we have 150 flowers

# %%
data1["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data1["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#our data set is balanced data set based on species column.

# %%
data1.drop(["Id"],axis=1,inplace=True)

# %%
data1.describe() #desriptive statistics about the data set
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data1.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
data1.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data1["SepalLengthCm"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
x1=np.percentile(data1["SepalLengthCm"],[25,50,100])

# %%
x1
# Out:
# array([5.1, 5.8, 7.9])

# %%
q1=x1[0]
q2=x1[1]
q3=x1[2]

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 2.8000000000000007

# %%
lb=q1-(1.5*iqr)

# %%
lb
# Out:
# 0.8999999999999986

# %%
up=q3+(1.5*iqr)

# %%
up
# Out:
# 12.100000000000001

# %%
data1.loc[data1["SepalLengthCm"]<lb]
# Out:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
data1.loc[data1["SepalLengthCm"]>up]
# Out:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
data1["SepalWidthCm"]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
x2=np.percentile(data1["SepalWidthCm"],[25,50,75])

# %%
x2
# Out:
# array([2.8, 3. , 3.3])

# %%
q1=x2[0]
q2=x2[1]
q3=x2[1]

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 0.20000000000000018

# %%
lb=q1-(1.5*iqr)

# %%
up=q3+(1.5*iqr)

# %%
data1.loc[data1["SepalWidthCm"]<lb]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 41             4.5           2.3            1.3           0.3      Iris-setosa
# 53             5.5           2.3            4.0           1.3  Iris-versicolor
# 57             4.9           2.4            3.3           1.0  Iris-versicolor
# 60             5.0           2.0            3.5           1.0  Iris-versicolor
# 62             6.0           2.2            4.0           1.0  Iris-versicolor
# 68             6.2           2.2            4.5           1.5  Iris-versicolor
# 80             5.5           2.4            3.8           1.1  Iris-versicolor
# 81             5.5           2.4            3.7           1.0  Iris-versicolor
# 87             6.3           2.3            4.4           1.3  Iris-versicolor
# 93             5.0           2.3            3.3           1.0  Iris-versicolor
# 119            6.0           2.2            5.0           1.5   Iris-virginica

# %%
data1.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
for y in data1.columns[0:4]:
    p=np.percentile(data1[y],[25,50,75])
    q1=p[0]
    q2=p[1]
    q3=p[2]
    iqr=q3-q1
    lb=q1-(1.5*iqr)
    up=q3+(1.5*iqr)
    print(y)
    print(data1.loc[data1[y]<lb])
    print("_ _ _ _ _ _ _ _ _ _ _ _ _ _")
    print(data1.loc[data1[y]>up])
# Out:
# SepalLengthCm
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
# SepalWidthCm
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 60            5.0           2.0            3.5           1.0  Iris-versicolor
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15            5.7           4.4            1.5           0.4  Iris-setosa
# 32            5.2           4.1            1.5           0.1  Iris-setosa
# 33            5.5           4.2            1.4           0.2  Iris-setosa
# PetalLengthCm
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
# PetalWidthCm
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
import seaborn as sb

# %%
sb.boxplot(data1["SepalWidthCm"])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
data1.boxplot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data1["SepalLengthCm"],data1["SepalWidthCm"])
plt.xlabel("SepalLength")
plt.ylabel("SepalWidth")
plt.title("SL vs SW")
# Out:
# Text(0.5, 1.0, 'SL vs SW')

# %%
plt.plot(data1["SepalLengthCm"],data1["SepalWidthCm"],linestyle="",marker="o",color="r",markersize=5)
plt.xlabel("SepalLength")
plt.ylabel("SepalWidth")
plt.title("SL vs SW")
# Out:
# Text(0.5, 1.0, 'SL vs SW')

# %%
setosa=data1.loc[data1["Species"]=="Iris-setosa"]
versicolor=data1.loc[data1["Species"]=="Iris-versicolor"]
ver=data1.loc[data1["Species"]=="Iris-virginica"]

# %%
data1["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # 1.SepalLength vs SepalWidth

# %%
plt.plot(setosa["SepalLengthCm"],setosa["SepalWidthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["SepalLengthCm"],versicolor["SepalWidthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["SepalLengthCm"],ver["SepalWidthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("SepalLength")
plt.ylabel("SepalWidth")
plt.title("SL vs SW")
plt.legend()

# %% [markdown]
# # 2.SepalLength vs PetalLength

# %%
plt.plot(setosa["SepalLengthCm"],setosa["PetalLengthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["SepalLengthCm"],versicolor["PetalLengthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["SepalLengthCm"],ver["PetalLengthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("SepalLength")
plt.ylabel("PetalLength")
plt.title("SL vs PL")
plt.legend()

# %% [markdown]
# # 3.SepalLength vs PetalWidth

# %%
plt.plot(setosa["SepalLengthCm"],setosa["PetalWidthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["SepalLengthCm"],versicolor["PetalWidthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["SepalLengthCm"],ver["PetalWidthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("SepalLength")
plt.ylabel("PetalWidth")
plt.title("SL vs PW")
plt.legend()

# %% [markdown]
# # 4. SepalWidth vs PetalLength

# %%
plt.plot(setosa["SepalWidthCm"],setosa["PetalLengthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["SepalWidthCm"],versicolor["PetalLengthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["SepalWidthCm"],ver["PetalLengthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("SepalWidth")
plt.ylabel("PetalLength")
plt.title("SW vs PL")
plt.legend()

# %% [markdown]
# # 5.SepalWidth vs PetalWidth

# %%
plt.plot(setosa["SepalWidthCm"],setosa["PetalWidthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["SepalWidthCm"],versicolor["PetalWidthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["SepalWidthCm"],ver["PetalWidthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("SepalWidth")
plt.ylabel("PetalWidth")
plt.title("SW vs PW")
plt.legend()

# %% [markdown]
# # 6. PetalLength vs PetalWidth

# %%
plt.plot(setosa["PetalLengthCm"],setosa["PetalWidthCm"],linestyle="",marker="o",color="r",markersize=5,label="setosa")
plt.plot(versicolor["PetalLengthCm"],versicolor["PetalWidthCm"],linestyle="",marker="o",color="b",markersize=5,label="versicolor")
plt.plot(ver["PetalLengthCm"],ver["PetalWidthCm"],linestyle="",marker="o",color="k",markersize=5,label="ver")
plt.xlabel("PetalLength")
plt.ylabel("PetalWidth")
plt.title("PL vs PW")
plt.legend()

# %%
plt.scatter(setosa["PetalLengthCm"],setosa["PetalWidthCm"],color="r",marker="d")

# %%
import seaborn as sns

# %%
sns.scatterplot(data=data1,x="SepalLengthCm",y="SepalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
setosa=data1.loc[data1["Species"]=="Iris-setosa"]
versicolor=data1.loc[data1["Species"]=="Iris-versicolor"]
ver=data1.loc[data1["Species"]=="Iris-virginica"]

# %%
sns.distplot(setosa["PetalLengthCm"])
sns.distplot(versicolor["PetalLengthCm"])
sns.distplot(ver["PetalLengthCm"])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.distplot(setosa["PetalWidthCm"])
sns.distplot(versicolor["PetalWidthCm"])
sns.distplot(ver["PetalWidthCm"])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %%
sns.distplot(setosa["SepalLengthCm"])
sns.distplot(versicolor["SepalLengthCm"])
sns.distplot(ver["SepalLengthCm"])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.distplot(setosa["SepalWidthCm"])
sns.distplot(versicolor["SepalWidthCm"])
sns.distplot(ver["SepalWidthCm"])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.displot(data=data1,x="SepalLengthCm",hue="Species",kind="kde")

# %%
sns.displot(data=data1,x="PetalLengthCm",hue="Species",kind="kde")

# %% [markdown]
# # Map:
# It is a series function used to mapping

# %%
data1["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data1["Species"]=data1["Species"].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
data1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
data1["Species"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %% [markdown]
# # apply():
# It is applied to both series and dataframe function.
# apply is applied to series elementwise,functions can be inbuilt,user-defined or Anonymus

# %%
data1["Species"].apply(complex)
# Out:
# 0      0.0+0.0j
# 1      0.0+0.0j
# 2      0.0+0.0j
# 3      0.0+0.0j
# 4      0.0+0.0j
#          ...
# 145    2.0+0.0j
# 146    2.0+0.0j
# 147    2.0+0.0j
# 148    2.0+0.0j
# 149    2.0+0.0j
# Name: Species, Length: 150, dtype: complex128

# %%
data1["Species"].apply(bool)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Species, Length: 150, dtype: bool

# %% [markdown]
# # apply():
# it is applied on dataframe axis wise

# %%
data1[["SepalLengthCm"]].apply(list)
# Out:
#      SepalLengthCm
# 0              5.1
# 1              4.9
# 2              4.7
# 3              4.6
# 4              5.0
# ..             ...
# 145            6.7
# 146            6.3
# 147            6.5
# 148            6.2
# 149            5.9
#
# [150 rows x 1 columns]

# %%
data1[["SepalLengthCm","SepalWidthCm"]].apply(sum,axis=1)
# Out:
# 0      8.6
# 1      7.9
# 2      7.9
# 3      7.7
# 4      8.6
#       ...
# 145    9.7
# 146    8.8
# 147    9.5
# 148    9.6
# 149    8.9
# Length: 150, dtype: float64

# %%
data1[["SepalLengthCm","SepalWidthCm"]].apply(sum,axis=0)
# Out:
# SepalLengthCm    876.5
# SepalWidthCm     458.1
# dtype: float64

# %%
data1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# # applymap():
# it is only used on dataframe elementwise.

# %%
data1[["SepalLengthCm","SepalWidthCm"]].applymap(complex)
# Out:
#      SepalLengthCm  SepalWidthCm
# 0         5.1+0.0j      3.5+0.0j
# 1         4.9+0.0j      3.0+0.0j
# 2         4.7+0.0j      3.2+0.0j
# 3         4.6+0.0j      3.1+0.0j
# 4         5.0+0.0j      3.6+0.0j
# ..             ...           ...
# 145       6.7+0.0j      3.0+0.0j
# 146       6.3+0.0j      2.5+0.0j
# 147       6.5+0.0j      3.0+0.0j
# 148       6.2+0.0j      3.4+0.0j
# 149       5.9+0.0j      3.0+0.0j
#
# [150 rows x 2 columns]

# %%
data1.rename
# Out:
# <bound method DataFrame.rename of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]>

# %%
x1=pd.DataFrame({"name":["Raghu p","raj T","tarun r"]})

# %%
x1
# Out:
#       name
# 0  Raghu p
# 1    raj T
# 2  tarun r

# %%
x1["name"].str.split()
# Out:
# 0    [Raghu, p]
# 1      [raj, T]
# 2    [tarun, r]
# Name: name, dtype: object

# %%
x1["name"].apply(lambda x:x.split()[0])
# Out:
# 0    Raghu
# 1      raj
# 2    tarun
# Name: name, dtype: object

# %%
data1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.bar(data["Species"].unique(),[50,50,50])
plt.xlabel("Species")
# Out:
# Text(0.5, 0, 'Species')

# %%
sns.barplot(data["Species"].unique(),[50,50,50])
# Out:
# C:\Users\RAGHAVENDRA KUMAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
